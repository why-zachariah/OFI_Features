# %%
# OFI Feature Construction

# %%
#imports
from ofi_features import build_features

# %%
#load and preview
df = build_features('first_25000_rows.csv')
df.head()
# Out:
#   symbol                    minute  best_ofi   OFI_0   OFI_1   OFI_2   OFI_3  \
# 0   AAPL 2024-10-21 11:54:00+00:00     328.0   328.0   323.0    66.0   208.0
# 1   AAPL 2024-10-21 11:55:00+00:00   -1421.0 -1421.0  2519.0  1339.0   -74.0
# 2   AAPL 2024-10-21 11:56:00+00:00     132.0   132.0  -587.0  2013.0    15.0
# 3   AAPL 2024-10-21 11:57:00+00:00    -196.0  -196.0  1677.0    39.0  1337.0
# 4   AAPL 2024-10-21 11:58:00+00:00     390.0   390.0  -440.0   822.0    57.0
#
#    OFI_4   OFI_5   OFI_6   OFI_7   OFI_8   OFI_9  integrated_ofi  \
# 0  -89.0  -655.0   146.0     1.0  -512.0   -47.0        2.321604
# 1 -180.0  -358.0  -551.0   119.0  -526.0   834.0     -596.520081
# 2  -52.0  -328.0   124.0  -578.0   468.0  -547.0     -877.889559
# 3  265.0    34.0  -816.0  1009.0  -513.0   807.0      645.287097
# 4 -222.0  1552.0 -1075.0  -515.0 -1183.0 -1920.0      102.513685
#
#    cross_asset_ofi
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# ...

# %%
#optional plot
df.set_index('minute')['best_ofi'].plot(title='Best-Level OFI over Time')
# Out:
# <Axes: title={'center': 'Best-Level OFI over Time'}, xlabel='minute'>
